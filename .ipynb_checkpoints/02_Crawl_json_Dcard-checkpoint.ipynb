# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Dcard 工作版
#
#
# * check > Network > Preview(看內容) > Headers > **Request URL**
#   * https://www.dcard.tw/service/api/v2/forums/job/posts?popular=true&limit=30&before=239219465
# *   import `requests` , `json`

# %%
import requests
import json

# 跑100篇
url_dcard = "https://www.dcard.tw/service/api/v2/forums/job/posts?popular=true&limit=100&before=239219465"
response = requests.get(url_dcard)

# Check data type
print(type(response.json()))
# Out:
# <class 'list'>

# %%
raw = response.json()

# %%
print(type(raw[0]))
print(raw[0].keys())
# Out:
# <class 'dict'>
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'isModerator', 'layout', 'spoilerAlert', 'isSelectedPost', 'unsafe', 'enableNestedComment', 'totalCommentCount', 'withImages', 'withVideos', 'media', 'reportReasonText', 'supportedReactions', 'excerptComments', 'edited', 'collectionCount', 'postAvatar', 'activityAvatar', 'verifiedBadge', 'memberType'])

# %%
# print(response.status_code)
# print(response.headers)
# print(response.text)

# %%
import pandas as pd
data = pd.DataFrame(raw)
data.head(10)
# Out:
#           id            title  \
# 0  239217154         有什麼很閒的工作
# 1  239226968      爭鮮離職還可以回去嗎？
# 2  239226861        藏壽司跟壽司郎打工
# 3  239226841     為什麼職缺都不寫清楚阿?
# 4  239226713           離職的理由?
# 5  239226071      抱怨一下主管的奇怪行為
# 6  239224080           超商暑期打工
# 7  239222047  證券業業務員　需要哪些金融證照
# 8  239220940          上銀科技 工讀
# 9  239219312         PT or 正職
#
#                                              excerpt  anonymousSchool  \
# 0  本人護理系出身，之前做了一份超閒的診所工作，不用掛號也不用打掃也不用去幫忙藥局，薪水37k，...             True
# 1               我想回去爭鮮打工，之前離職原因是因為跟員工吵架，但其實我覺得整體環境還行             True
# 2  這邊想請問幾個問題，藏壽司跟壽司郎都有供餐嗎？還是沒有（或是晚班收店有食物），藏壽司跟壽司郎...             True
# 3  搞不懂一堆職缺都不先寫清楚，浪費彼此時間 真的不解，輪班 時間範圍不能給嗎？ 做六休二也是輪...             True
# 4  這樣子的，小妹做了快三個月，最近被老闆加薪水，.......，雖然很sorry，但是，我.....             True
# 5  1.，實習生（學生）最後一天來送餅乾，謝謝我們的照顧（一人一份），結果主管直接把餅乾退回去說...             True
# 6  被問要應徵暑期還是長期到底該怎麼回答啊？今年剛畢業要升大一，想趁暑假去打工，但因為大學離家比...             True
# 7  就我進去凱基證券而言，需要的是，證券業業務員，期貨商業務員，信託業務人員，人身保險業務員，財...            False
# 8  想問有沒有人有在上銀工讀過，Google搜尋上銀出來的都是有關正職的負面評價，想知道工讀的環...             True
# 9  昨天剛畢業，打算結束北漂回南部，這陣子也有一直在找工作，但家人一直問工作的事 真的讓人頭痛…...             True
#
#    anonymousDepartment  pinned                               forumId  replyId  \
# 0                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 1                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 2                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 3                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 4                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 5                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 6                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 7                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 8                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
# 9                 True   False  6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444      NaN
#
#                   createdAt                 updatedAt  ...  postAvatar  \
# 0  2022-06-19T06:59:41.312Z  2022-06-19T06:59:41.312Z  ...
# 1  2022-06-20T08:26:58.944Z  2022-06-20T08:26:58.944Z  ...
# 2  2022-06-20T08:13:42.413Z  2022-06-20T08:36:03.380Z  ...
# 3  2022-06-20T08:11:45.392Z  2022-06-20T08:11:45.392Z  ...
# 4  2022-06-20T07:56:44.159Z  2022-06-20T07:57:57.466Z  ...
# 5  2022-06-20T06:42:21.798Z  2022-06-20T06:42:21.798Z  ...
# 6  2022-06-20T02:16:47.670Z  2022-06-20T02:16:47.670Z  ...
# 7  2022-06-19T16:44:57.630Z  2022-06-19T16:45:57.846Z  ...
# 8  2022-06-19T14:47:20.666Z  2022-06-19T14:47:20.666Z  ...
# 9  2022-06-19T11:38:20.446Z  2022-06-19T11:38:20.446Z  ...
#
#    activityAvatar  verifiedBadge memberType enablePrivateMessage school  \
# 0                          False                             NaN    NaN
# 1                          False                             NaN    NaN
# 2                          False                           False    NaN
# 3                          False                             NaN    NaN
# 4                          False                           False    NaN
# 5                          False                             NaN    NaN
# 6                          False                             NaN    NaN
# 7                          False                           False   ting
# 8                          False                             NaN    NaN
# 9                          False                             NaN    NaN
#
#      department leaderboardCategoryId  leaderboardCategoryName leaderboardRank
# 0           NaN                   NaN                      NaN             NaN
# 1           NaN                   NaN                      NaN             NaN
# 2           NaN                   NaN                      NaN             NaN
# 3           NaN                   NaN                      NaN             NaN
# 4           NaN                   NaN                      NaN             NaN
# 5           NaN                   NaN                      NaN             NaN
# 6           NaN                   NaN                      NaN             NaN
# 7  chrissamting                   NaN                      NaN             NaN
# 8           NaN                   NaN                      NaN             NaN
# 9           NaN                   NaN                      NaN             NaN
#
# [10 rows x 51 columns]

# %% [markdown]
# ## 爬取完整內文
# 由於excerpt欄位中不包含完整內文，故抓出id後爬取
# * URL: "https://www.dcard.tw/service/api/v2/posts/" + "ID"
# * 只抓取部分需要欄位
#   * id, title, content, createdAt, updatedAt, forumName, gender, likeCount, reactions, topics

# %% [markdown]
# ### Write a function to crawl data

# %%
def Crawl(ID):
    url_dcard = "https://www.dcard.tw/service/api/v2/posts/" + str(ID)
    requ = requests.get(url_dcard)
    rejs = requ.json()
    posts = dict()
    
    posts['ID'] = rejs['id']
    posts['title'] = rejs['title']
    posts['content'] = rejs['content']
    posts['createdAt'] = rejs['createdAt']
    posts['updatedAt'] = rejs['updatedAt'],
    posts['commentCount'] = rejs['commentCount']
    posts['forumName'] = rejs['forumName']
    posts['forumAlias']  = rejs['forumAlias']
    posts['gender'] = rejs['gender']
    posts['likeCount'] = rejs['likeCount']
    posts['topics'] = rejs['topics']

    return posts

# %%
id_list = list(data['id'])

# %% [markdown]
# ### 分次跑貼文
# 一次跑全部id很容易被擋(JSONecodeError),嘗試一次30篇

# %%
# 容易被擋
posts_list = []
for id in id_list:
  posts_list.append(Crawl(id))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-9fbb0718fdaa> in <module>()
#       2 posts_list = []
#       3 for id in id_list:
# ----> 4   posts_list.append(Crawl(id))
#
# <ipython-input-6-e917c5fcd68c> in Crawl(ID)
#       2     url_dcard = "https://www.dcard.tw/service/api/v2/posts/" + str(ID)
#       3     requ = requests.get(url_dcard)
# ----> 4     rejs = requ.json()
#       5     posts = dict()
#       6
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /usr/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# 嘗試每爬20篇休息25分鐘
from time import sleep
posts_list = []

for i in range(len(data)):
  print(i)
  if i > 0 and i%20 == 0:
    print("休25分鐘")
    sleep(1500)
  try:
    posts_list.append(Crawl(id_list[i]))
  except KeyError:
    pass

# %% [markdown]
# ## 輸出成CSV檔

# %%
df_post = pd.DataFrame(posts_list)
df_post
# Out:
#            ID                  title  \
# 0   239217154               有什麼很閒的工作
# 1   239226968            爭鮮離職還可以回去嗎？
# 2   239226861              藏壽司跟壽司郎打工
# 3   239226841           為什麼職缺都不寫清楚阿?
# 4   239226713                 離職的理由?
# ..        ...                    ...
# 94  239229764            如何才能找到編輯的實習
# 95  239229624  我的天才老闆Part2-千錯萬錯都是你的錯
# 96  239229583              做不是本科系的工作
# 97  239229541                暫時回家中幫忙
# 98  239229417               薪水差不多的工作
#
#                                               content  \
# 0   本人護理系出身，之前做了一份超閒的診所工作，不用掛號也不用打掃也不用去幫忙藥局，薪水37k，...
# 1              我想回去爭鮮打工\n之前離職原因是因為跟員工吵架\n但其實我覺得整體環境還行
# 2   這邊想請問幾個問題\n藏壽司跟壽司郎都有供餐嗎？還是沒有（或是晚班收店有食物）\n藏壽司跟壽...
# 3   搞不懂一堆職缺都不先寫清楚 \n浪費彼此時間 真的不解\n輪班 時間範圍不能給嗎? 做六休二...
# 4   這樣子的,小妹做了快三個月,最近被老闆加薪水,.......,\n雖然很sorry,\n但是...
# ..                                                ...
# 94  大家好🌝這是我第一次發文（緊張\n這件事真的困擾我好一陣子 一直想不太到解決方法\n之前在人...
# 95  不知道各位的老闆or主管是否都是個明理的人\n如果是，恭喜\n如果不是，這悲劇的路上有我有你...
# 96  大家好，我是應屆畢業生，大學是念大眾傳播相關科系，但不是走新聞影視方面，是活動、行銷類的，家...
# 97  如果家裡做生意但“沒有登記”\n剛畢業就回家幫忙工作...以後再出來外面找工作的話，該如何解...
# 98  1. 小小設備商 38k\n一個月要輪一次晚班（一天400）\n六日也要值班on call（...
#
#                    createdAt                    updatedAt  commentCount  \
# 0   2022-06-19T06:59:41.312Z  (2022-06-19T06:59:41.312Z,)             3
# 1   2022-06-20T08:26:58.944Z  (2022-06-20T08:26:58.944Z,)             4
# 2   2022-06-20T08:13:42.413Z  (2022-06-20T08:36:03.380Z,)             2
# 3   2022-06-20T08:11:45.392Z  (2022-06-20T08:11:45.392Z,)             3
# 4   2022-06-20T07:56:44.159Z  (2022-06-20T07:57:57.466Z,)             5
# ..                       ...                          ...           ...
# 94  2022-06-20T13:36:48.827Z  (2022-06-20T13:36:48.827Z,)             1
# 95  2022-06-20T13:22:50.965Z  (2022-06-20T13:24:45.160Z,)             2
# 96  2022-06-20T13:18:23.146Z  (2022-06-20T13:18:23.146Z,)             2
# 97  2022-06-20T13:15:11.564Z  (2022-06-20T13:18:57.691Z,)             1
# 98  2022-06-20T13:05:11.735Z  (2022-06-20T13:14:13.010Z,)             2
#
#    forumName forumAlias gender  likeCount                topics
# 0         工作        job      F          4  [工作, 職場, 請益, 求職, 上班]
# 1         工作        job      M          3    [工作, 疫情, 工作經驗, 實習]
# 2         工作        job      M          3          [工作, 實習, 打工]
# 3         工作        job      M          4                  [工作]
# 4         工作        job      F          5              [離職, 工作]
# ..       ...        ...    ...        ...                   ...
# 94        工作        job      F          1  [編輯, 實習, 打工, 徵才, 求職]
# 95        工作        job      F          1      [老闆, 工作, 上班, 公司]
# 96        工作        job      F          0         [工作, 新鮮人, 求職]
# 97        工作        job      M          0                  [工作]
# 98        工作        job      M          0  [薪水, 工作, 求職, 面試, 請益]
#
# [99 rows x 11 columns]

# %%
df_post.to_csv('post_list.csv', encoding='utf_8_sig')
