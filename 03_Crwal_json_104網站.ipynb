# %% [markdown]
# # Web Screping 104.com
# * 搜尋頁面: '數據分析'
# * check > Network > Preview(看內容) > Headers > Request URL
#   * https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page=2&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1

# %%
url_104 = "https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page=2&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ## 失敗的方式

# %%
response = requests.get(url_104)

# %%
print(response.status_code)
print(response.headers)
print(response.text)  # 未成功讀取資料
# Out:
# 200
# {'Cache-Control': 'no-cache', 'Connection': 'close', 'Pragma': 'no-cache', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '293'}
# <html xmlns="http://www.w3.org/1999/xhtml"><head><META HTTP-EQUIV="CONTENT-TYPE" CONTENT="TEXT/HTML; CHARSET=utf-8"/><title></title></head>
# <body>
# <SCRIPT LANGUAGE="JavaScript">
# window.location="https://www.104.com.tw/jobs/main/syserr?eid=11093197866354903827";
# </script>
# </body>
# </html>

# %%
# 把回傳的結果寫入html檔，看錯誤訊息為何
with open('temp_output.html', 'w') as fout:
    fout.write(response.text)
fout.close()

# webbrowser cannot work, but why?
import webbrowser
webbrowser.open_new_tab('temp_output.html')
# Out:
# False

# %% [markdown]
# ## Add referer
# * User-Agent: 使用什麼瀏覽器或系統
# * Referer: 從哪個頁面點選、跳轉過來
# * Cookies: 經過與伺服器建立連結後, 伺服器給了什麼資訊
# * (多半headers會從User-agent測起，再來Referer, 再來cookies)

# %%
url_104 = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page=2&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1'
headers = {'referer': 'https://www.104.com.tw/'}
# headers = {'user agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'}
raw = requests.get(url_104, headers=headers).json()
print(response.text)
print(type(raw))
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head><META HTTP-EQUIV="CONTENT-TYPE" CONTENT="TEXT/HTML; CHARSET=utf-8"/><title></title></head>
# <body>
# <SCRIPT LANGUAGE="JavaScript">
# window.location="https://www.104.com.tw/jobs/main/syserr?eid=11093197866354903827";
# </script>
# </body>
# </html>
# <class 'dict'>

# %% [markdown]
# ### check data and get total_page

# %%
print(raw.keys())
print(type(raw['data']))
print(raw['data'].keys())
print(raw['data']['totalPage'])
print(raw['data']['totalCount'])
print(raw['data']['pageNo'])
print(raw['data']['list'])  # 要的資料
pd.DataFrame(raw['data']['list'])
# Out:
# dict_keys(['status', 'action', 'data', 'statusMsg', 'errorMsg'])
# <class 'dict'>
# dict_keys(['query', 'filterDesc', 'queryDesc', 'list', 'count', 'pageNo', 'totalPage', 'totalCount'])
# 150
# 8966
# 2
# [{'jobType': '0', 'jobNo': '12442764', 'jobName': '運動數據分析 影像處理工程師 image recognition ', 'jobNameSnippet': "運動<em class='b-txt--highlight'>數據分析</em> 影像處理工程師 image recognition ", 'jobRole': '1', 'jobRo': '1', 'jobAddrNo': '6001002015', 'jobAddrNoDesc': '新北市中和區', 'jobAddress': '新北市中和區連城路347巷2弄13號', 'description': 'Bucket Analytics是致力於推動運動產業與人工智慧技術的結合的新創公司，目前聚焦於提供籃球賽事的服務及產品，我們在尋找同樣熱愛籃球的夥伴！\n\n1.工作時間有效完成任務\n2.負責影像辨識軟體之分析、設計以及程式撰寫。\n3.規劃執行軟體架構及模組之設計，並控管軟體設計進度。\n4.進行軟體之測試與修改。\n5.規劃、執行與維護量產的產品。', 'optionEdu': '大學', 'period': '00', 'periodDesc': '經歷不拘', 'applyCnt': '00009', 'applyDesc': '6~10人應徵', 'custNo': '130000000177109', 'custName': '球據智能運動數據分析有限公司', 'coIndustry': '1001001002', 'coIndustryDesc': '電腦軟體服務業', 'salaryLow': '0000000', 'salaryHigh': '0000000', 'salaryDesc': '待遇面議', 's10': '10', 'appearDate': '20220614', 'appearDateDesc': '6/14', 'optionZone': '0', 'isApply': '0', 'applyDate': '', 'isSave': '0', 'descSnippet': 'Bucket Analytics是致力於推動運動產業與人工智慧技術的結合的新創公司，目前聚焦於提供籃球賽事的服務及產品，我們在尋找同樣熱愛籃球的夥伴！\n\n1.工作時間有效完成任務\n2.負責影像辨識軟體之分析、設計以及程式撰寫。\n3.規劃執行軟體架構及模組之設計，並控管軟體設計進度。\n4.進行軟體之測試與修改。\n5.規劃、執行與維護量產的產品。', 'tags': ['員工10人', '遠端工作'], 'landmark': '', 'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7eowc?channel=104rpt&jobsource=apply_analyze', 'job': '//www.104.com.tw/job/7eowc?jobsource=jolist_b_relevance', 'cust': '//www.104.com.tw/company/1a2x6blryt?jobsource=jolist_b_relevance'}, 'jobsource': 'jolist_b_relevance', 'jobNameRaw': '運動數據分析 影像處理工程師 image recognition ', 'custNameRaw': '球據智能運動數據分析有限公司', 'lon': '121.4876163', 'lat': '24.9957125', 'remoteWorkType': 2, 'major': []}, {'jobType': '0', 'jobNo': '11058684', 'jobName': 'AI數據分析工程師', 'jobNameSnippet': "AI<em class='b-txt--highlight'>數據分析</em>工程師", 'jobRole': '1', 'jobRo': '1', 'jobAddrNo': '6001001003', 'jobAddrNoDesc': '台北市中山區', 'jobAddress': '南京東路二段97號5樓', 'description': '1.利用機器學習/深度學習等技術，分析資料提供解決方案 \n2.負責[[[數據分析]]]自動化流程開發 \n3. 數據特徵分析及處理功能開發\n4. [[[數據分析]]]可視化顯示及分析結果整理 \n5. 新模型或演算法研究及整合\n', 'optionEdu': '大學', 'period': '00', 'periodDesc': '經歷不拘', 'applyCnt': '00016', 'applyDesc': '11~30人應徵', 'custNo': '130000000049234', 'custName': '科智企業股份有限公司', 'coIndustry': '1001001002', 'coIndustryDesc': '電腦軟體服務業', 'salaryLow': '0000000', 'salaryHigh': '0000000', 'salaryDesc': '待遇面議', 's10': '10', 'appearDate': '20220618', 'appearDateDesc': '6/18', 'optionZone': '0', 'isApply': '0', 'applyDate': '', 'isSave': '0', 'descSnippet': "1.利用機器學習/深度學習等技術，分析資料提供解決方案 \n2.負責<em class='b-txt--highlight'>數據分析</em>自動化流程開發 \n3. 數據特徵分析及處理功能開發\n4. <em class='b-txt--highlight'>數據分析</em>可視化顯示及分析結果整理 \n5. 新模型或演算法研究及整合\n", 'tags': ['員工23人'], 'landmark': '距捷運松江南京站70公尺', 'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/6l0xo?channel=104rpt&jobsource=apply_analyze', 'job': '//www.104.com.tw/job/6l0xo?jobsource=jolist_b_relevance', 'cust': '//www.104.com.tw/company/1a2x6bj1aq?jobsource=jolist_b_relevance'}, 'jobsource': 'jolist_b_relevance', 'jobNameRaw': 'AI數據分析工程師', 'custNameRaw': '科智企業股份有限公司', 'lon': '121.5323119', 'lat': '25.052299', 'remoteWorkType': 0, 'major': []}, {'jobType': '2', 'jobNo': '12418872', 'jobName': '數據分析師.', 'jobNameSnippet': "<em class='b-txt--highlight'>數據分析</em>師.", 'jobRole': '1', 'jobRo': '1', 'jobAddrNo': '6001001005', 'jobAddrNoDesc': '台北市大安區', 'jobAddress': '敦化南路二段77號12樓', 'description': '1.利用[[[數據分析]]]解決商業問題\n2.跨部門專案溝通合作\n3.營運績效追蹤與評估\n4.日常營運及管理報表製作\n5.其他數據研究分析與簡報報告', 'optionEdu': '大學', 'period': '00', 'periodDesc': '經歷不拘', 'applyCnt': '00019', 'applyDesc': '11~30人應徵', 'custNo': '22760834000', 'custName': '永慶房產集團_永慶房屋仲介股份有限公司', 'coIndustry': '1011004001', 'coIndustryDesc': '不動產經營業', 'salaryLow': '0000000', 'salaryHigh': '0000000', 'salaryDesc': '待遇面議', 's10': '10', 'appearDate': '20220606', 'appearDateDesc': '6/06', 'optionZone': '2101376', 'isApply': '0', 'applyDate': '', 'isSave': '0', 'descSnippet': "1.利用<em class='b-txt--highlight'>數據分析</em>解決商業問題\n2.跨部門專案溝通合作\n3.營運績效追蹤與評估\n4.日常營運及管理報表製作\n5.其他數據研究分析與簡報報告", 'tags': ['員工3000人'], 'landmark': '距捷運信義安和站500公尺', 'link': ...
#    jobType     jobNo                                 jobName  \
# 0        0  12442764       運動數據分析 影像處理工程師 image recognition
# 1        0  11058684                               AI數據分析工程師
# 2        2  12418872                                  數據分析師.
# 3        0  10589685  Data Scientist 資料科學家_數據分析師 | CBU_21_13
# 4        2  12638698                                   數據分析師
# 5        0  12846559               數據分析師_Data Analyst_PaGamO
# 6        0  12868383                                   數據分析師
# 7        2  12742577                                  數據分析人員
# 8        2  11742822                               統一超商數據分析師
# 9        0  11742920                                 品牌數據分析師
# 10       0  12858833                                   數據分析師
# 11       2  12797814                   研發類--數據分析暨製程AI工程師(中科)
# 12       2  12222193                                 遊戲數據分析師
# 13       0  12838398                    Data analyst / 數據分析師
# 14       2  12450913              D429 產業研究分析師/ 數據分析師(可遠端工作)
# 15       0  12861852                   Data Analyst  | 數據分析師
# 16       0  12841566                            系統與數據分析師-AP2
# 17       0  12402552                             客戶暨系統數據分析專員
# 18       0  12841689                               數據分析師(碩士)
# 19       0  12782500                                 行銷數據分析師
#
#                                        jobNameSnippet jobRole jobRo  \
# 0   運動<em class='b-txt--highlight'>數據分析</em> 影像處理工...       1     1
# 1         AI<em class='b-txt--highlight'>數據分析</em>工程師       1     1
# 2            <em class='b-txt--highlight'>數據分析</em>師.       1     1
# 3   Data Scientist 資料科學家_<em class='b-txt--highlig...       1     1
# 4             <em class='b-txt--highlight'>數據分析</em>師       1     1
# 5   <em class='b-txt--highlight'>數據分析</em>師_Data A...       1     1
# 6             <em class='b-txt--highlight'>數據分析</em>師       1     1
# 7            <em class='b-txt--highlight'>數據分析</em>人員       1     1
# 8         統一超商<em class='b-txt--highlight'>數據分析</em>師       1     1
# 9           品牌<em class='b-txt--highlight'>數據分析</em>師       1     1
# 10            <em class='b-txt--highlight'>數據分析</em>師       1     1
# 11  研發類--<em class='b-txt--highlight'>數據分析</em>暨製程...       1     1
# 12          遊戲<em class='b-txt--highlight'>數據分析</em>師       1     1
# 13  Data analyst / <em class='b-txt--highlight'>數據...       1     1
# 14  D429 產業研究分析師/ <em class='b-txt--highlight'>數據分...       1     1
# 15  Data Analyst  | <em class='b-txt--highlight'>數...       1     1
# 16     系統與<em class='b-txt--highlight'>數據分析</em>師-AP2       1     1
# 17      客戶暨系統<em class='b-txt--highlight'>數據分析</em>專員       1     1
# 18        <em class='b-txt--highlight'>數據分析</em>師(碩士)       1     1
# 19          行銷<em class='b-txt--highlight'>數據分析</em>師       1     1
#
#      jobAddrNo jobAddrNoDesc          jobAddress  \
# 0   6001002015        新北市中和區  新北市中和區連城路347巷2弄13號
# 1   6001001003        台北市中山區         南京東路二段97號5樓
# 2   6001001005        台北市大安區        敦化南路二段77號12樓
# 3   6001002020        新北市三重區      三和路四段111之32號7樓
# 4   6001001005        台北市大安區        忠孝東路四段285號4樓
# 5   6001001001        台北市中正區       羅斯福路2段9號11樓之1
# 6   6001001010        台北市內湖區
# 7   6001001011        台北市南港區         經貿二路188號14樓
# 8   6001001007        台北市信義區            東興路65號2樓
# 9   6001001005        台北市大安區        敦化南路二段59號16樓
# 10  6001001004        台北市松山區        南京東路四段18號15樓
# 11  6001008020        台中市大雅區
# 12  6001001007        台北市信義區        市民大道6段288號7樓
# 13  6003002000           東南亞
# 14  6001001007        台北市信義區
# 15  6001001010        台北市內湖區
# 16  6001001001        台北市中正區      杭州南路一段23號11樓之3
# 17  6001001007        台北市信義區
# 18  6001008007        台中市西屯區            安和東路3號6樓
# 19  6001001007        台北市信義區         基隆路一段178號5樓
#
#                                           description  ...  \
# 0   Bucket Analytics是致力於推動運動產業與人工智慧技術的結合的新創公司，目前聚焦...  ...
# 1   1.利用機器學習/深度學習等技術，分析資料提供解決方案 \n2.負責[[[數據分析]]]自動...  ...
# 2   1.利用[[[數據分析]]]解決商業問題\n2.跨部門專案溝通合作\n3.營運績效追蹤與評估...  ...
# 3   面對真實世界的複雜問題，運用資料科學與[[[數據分析]]]專業，協助客戶掌握有價值的資料並獲...  ...
# 4   *** 工作內容\n1.數據探勘\n2.產業數據研究分析與報告撰寫\n3.數據資料庫維運\n...  ...
# 5   穩定易用。\n作為 PaGamO 的[[[數據分析]]]師, 不只能與頂尖的工程師、設計師、...  ...
# 6   1.協助管理用戶行為資料，並根據需求進行資料處理。\n2.依照需求進行用戶[[[數據分析]]...  ...
# 7   1. 集中市場交易[[[數據分析]]]\n2. 建置及維護數據資料庫\n3. 衍生性商品行政...  ...
# 8   1. 會員行為觀測與分析，產生可執行的數據洞察，並可轉換為商業價值。\n2. 會員行銷活動[...  ...
# 9   1.協助品牌提出台灣區市場[[[數據分析]]]及風險建議。\n2.依據業務主題，挖掘數據價值...  ...
# 10  職務說明：\n1. 透過[[[數據分析]]]與洞察得出有價值結果，共同達成Data-driv...  ...
# 11  【本職缺僅接受華邦官方網站投遞】\n請至華邦官方網站投遞個人履歷表，此職缺履歷登錄網\nht...  ...
# 12  工作內容摘要：\n1.協助管理用戶行為資料，並根據需求進行資料處理。\n2.依照需求進行用戶...  ...
# 13  識，具備利用[[[數據分析]]]問題、解決問題的能力；\n- 精通至少一種[[[數據分析]]...  ...
# 14  1. 根據內外部業務需求，提供[[[數據分析]]]與洞察\n2. 以商業應用角度解讀分析結果...  ...
# 15  1. 挖掘、觀察數據，提供產品數據洞察建議\n2. 營運數據彙整、分析，並透過圖形化報表呈現...  ...
# 16              系統分析、雛形製作、資料轉檔、報表製作、[[[數據分析]]]與建立預測模型  ...
# 17  工作內容:\n1.客戶[[[數據分析]]]及統整。\n2.維護客服品質。\n3.客戶數據處理...  ...
# 18  ***應徵時請附上作品集、文案、自傳、證照等加分文件***\n1.\t需求分析及規劃資料萃取...  ...
# 19  1. 執行各項數據彙整分析、營運報表產出\n2. 製作營運Dashboard ，提供[[[數...  ...
#
#                      tags         landmark  \
# 0           [員工10人, 遠端工作]
# 1                 [員工23人]     距捷運松江南京站70公尺
# 2               [員工3000人]    距捷運信義安和站500公尺
# 3                [員工300人]    距捷運三和國中站110公尺
# 4                 [員工58人]   距捷運國父紀念館站350公尺
# 5           [員工80人, 遠端工作]
# 6                 [員工30人]
# 7                [員工500人]  距捷運南港軟體園區站150公尺
# 8         [上市上櫃, 員工8775人]
# 9                 [員工30人]    距捷運信義安和站420公尺
# 10               [員工170人]   距捷運台北小巨蛋站180公尺
# 11        [上市上櫃, 員工2800人]
# 12               [員工520人]      距捷運松山站170公尺
# 13                     []
# 14  [上市上櫃, 員工3500人, 遠端工作]
# 15                     []
# 16                [員工72人]     距捷運善導寺站440公尺
# 17                [員工35人]
# 18               [員工200人]
# 19                [員工50人]     距捷運市政府站210公尺
#
#                                                  link           jobsource  \
# 0   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 1   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 2   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 3   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 4   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 5   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 6   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 7   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 8   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 9   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 10  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 11  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 12  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 13  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 14  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 15  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 16  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 17  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 18  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 19  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
#
#                                 jobNameRaw            custNameRaw  \
# 0        運動數據分析 影像處理工程師 image recognition          球據智能運動數據分析有限公司
# 1                                AI數據分析工程師             科智企業股份有限公司
# 2                                   數據分析師.    永慶房產集團_永慶房屋仲介股份有限公司
# 3   Data Scientist 資料科學家_數據分析師 | CBU_21_13          伊雲谷數位科技股份有限公司
# 4                                    數據分析師           聯樂數位行銷股份有限公司
# 5                數據分析師_Data Analyst_PaGamO  英屬維京群島商幫你優股份有限公司台灣分公司
# 6                                    數據分析師              播樂多娛樂有限公司
# 7                                   數據分析人員         中國信託綜合證券股份有限公司
# 8                                統一超商數據分析師             統一超商股份有限公司
# 9                                  品牌數據分析師             先聲數位服務有限公司
# 10                                   數據分析師            雨林新零售股份有限公司
# 11                   研發類--數據分析暨製程AI工程師(中科)             華邦電子股份有限公司
# 12                                 遊戲數據分析師           傳奇網路遊戲股份有限公司
# 13                    Data analyst / 數據分析師             智雲資訊服務有限公司
# 14              D429 產業研究分析師/ 數據分析師(可遠端工作)            台灣大哥大股份有限公司
# 15                   Data Analyst  | 數據分析師               創御軟體有限公司
# 16                            系統與數據分析師-AP2             探網科技股份有限公司
# 17                             客戶暨系統數據分析專員                 豐卉有限公司
# 18                               數據分析師(碩士)             弈樂科技股份有限公司
# 19                                 行銷數據分析師  EZTABLE_三二三網路科技股份有限公司
#
#             lon         lat remoteWorkType                         major
# 0   121.4876163  24.9957125              2                            []
# 1   121.5323119   25.052299              0                            []
# 2    121.549201   25.030284              0                            []
# 3   121.4856118  25.0774577              0                            []
# 4   121.5540532  25.0416769              0                            []
# 5                                        2      [資訊工程相關, 資訊管理相關, 數理統計相關]
# 6   121.5909027  25.0689422              0        [經濟學相關, 一般商業學類, 統計學相關]
# 7   121.6152597  25.0588446              0              [資訊管理相關, 資訊工程相關]
# 8   121.5666482  25.0468634              0                            []
# 9    121.549338  25.0313317              0               [統計學相關, 數理統計相關]
# 10  121.5536019  25.0514373              0                            []
# 11  120.6545022  24.2225023              0  [資訊管理相關, 數學及電算機科學學科類, 工程學科類]
# 12  121.5790844  25.0492674              0                            []
# 13                                       0                            []
# 14  121.5720055  25.0409201              2                            []
# 15  121.5909027  25.0689422              0                            []
# 16     121.5266  25.0422247              0                            []
# 17  121.5720055  25.0409201              0                            []
# 18  120.6236257  24.1743319              0       [數理統計相關, 統計學相關, 資訊管理相關]
# 19  121.5648794  25.0424777              0                            []
#
# [20 rows x 40 columns]

# %%
print(len(raw['data']['list']))
print(raw['data']['list'][0])
# Out:
# 20
# {'jobType': '0', 'jobNo': '12442764', 'jobName': '運動數據分析 影像處理工程師 image recognition ', 'jobNameSnippet': "運動<em class='b-txt--highlight'>數據分析</em> 影像處理工程師 image recognition ", 'jobRole': '1', 'jobRo': '1', 'jobAddrNo': '6001002015', 'jobAddrNoDesc': '新北市中和區', 'jobAddress': '新北市中和區連城路347巷2弄13號', 'description': 'Bucket Analytics是致力於推動運動產業與人工智慧技術的結合的新創公司，目前聚焦於提供籃球賽事的服務及產品，我們在尋找同樣熱愛籃球的夥伴！\n\n1.工作時間有效完成任務\n2.負責影像辨識軟體之分析、設計以及程式撰寫。\n3.規劃執行軟體架構及模組之設計，並控管軟體設計進度。\n4.進行軟體之測試與修改。\n5.規劃、執行與維護量產的產品。', 'optionEdu': '大學', 'period': '00', 'periodDesc': '經歷不拘', 'applyCnt': '00009', 'applyDesc': '6~10人應徵', 'custNo': '130000000177109', 'custName': '球據智能運動數據分析有限公司', 'coIndustry': '1001001002', 'coIndustryDesc': '電腦軟體服務業', 'salaryLow': '0000000', 'salaryHigh': '0000000', 'salaryDesc': '待遇面議', 's10': '10', 'appearDate': '20220614', 'appearDateDesc': '6/14', 'optionZone': '0', 'isApply': '0', 'applyDate': '', 'isSave': '0', 'descSnippet': 'Bucket Analytics是致力於推動運動產業與人工智慧技術的結合的新創公司，目前聚焦於提供籃球賽事的服務及產品，我們在尋找同樣熱愛籃球的夥伴！\n\n1.工作時間有效完成任務\n2.負責影像辨識軟體之分析、設計以及程式撰寫。\n3.規劃執行軟體架構及模組之設計，並控管軟體設計進度。\n4.進行軟體之測試與修改。\n5.規劃、執行與維護量產的產品。', 'tags': ['員工10人', '遠端工作'], 'landmark': '', 'link': {'applyAnalyze': '//www.104.com.tw/jobs/apply/analysis/7eowc?channel=104rpt&jobsource=apply_analyze', 'job': '//www.104.com.tw/job/7eowc?jobsource=jolist_b_relevance', 'cust': '//www.104.com.tw/company/1a2x6blryt?jobsource=jolist_b_relevance'}, 'jobsource': 'jolist_b_relevance', 'jobNameRaw': '運動數據分析 影像處理工程師 image recognition ', 'custNameRaw': '球據智能運動數據分析有限公司', 'lon': '121.4876163', 'lat': '24.9957125', 'remoteWorkType': 2, 'major': []}

# %% [markdown]
# ### get the next page urls
# 觀察到url的差異在page=的數字

# %%
total_page = (raw['data']['totalPage'])
total_page
# Out:
# 150

# %%
headers = {'referer': 'https://www.104.com.tw/'}

all_data = []
for page in range(1, total_page+1):
  url_104 = "https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page=" + str(page) + "&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"
  raw = requests.get(url_104, headers=headers).json()
  all_data.extend(raw['data']['list'])
  print(page, 'Data len', len(all_data))
# Out:
# 1 Data len 30
# 2 Data len 50
# 3 Data len 70
# 4 Data len 90
# 5 Data len 110
# 6 Data len 130
# 7 Data len 150
# 8 Data len 170
# 9 Data len 190
# 10 Data len 210
# 11 Data len 230
# 12 Data len 250
# 13 Data len 270
# 14 Data len 290
# 15 Data len 310
# 16 Data len 330
# 17 Data len 350
# 18 Data len 370
# 19 Data len 390
# 20 Data len 410
# 21 Data len 430
# 22 Data len 450
# 23 Data len 470
# 24 Data len 490
# 25 Data len 510
# 26 Data len 530
# 27 Data len 550
# 28 Data len 570
# 29 Data len 590
# 30 Data len 610
# 31 Data len 630
# 32 Data len 650
# 33 Data len 670
# 34 Data len 690
# 35 Data len 710
# 36 Data len 730
# 37 Data len 750
# 38 Data len 770
# 39 Data len 790
# 40 Data len 810
# 41 Data len 830
# 42 Data len 850
# 43 Data len 870
# 44 Data len 890
# 45 Data len 910
# 46 Data len 930
# 47 Data len 950
# 48 Data len 970
# 49 Data len 990
# 50 Data len 1010
# 51 Data len 1030
# 52 Data len 1050
# 53 Data len 1070
# 54 Data len 1090
# 55 Data len 1110
# 56 Data len 1130
# 57 Data len 1150
# 58 Data len 1170
# 59 Data len 1190
# 60 Data len 1210
# 61 Data len 1230
# 62 Data len 1250
# 63 Data len 1270
# 64 Data len 1290
# 65 Data len 1310
# 66 Data len 1330
# 67 Data len 1350
# 68 Data len 1370
# 69 Data len 1390
# 70 Data len 1410
# 71 Data len 1430
# 72 Data len 1450
# 73 Data len 1470
# 74 Data len 1490
# 75 Data len 1510
# 76 Data len 1530
# 77 Data len 1550
# 78 Data len 1570
# 79 Data len 1590
# 80 Data len 1610
# 81 Data len 1630
# 82 Data len 1650
# 83 Data len 1670
# 84 Data len 1690
# 85 Data len 1710
# 86 Data len 1730
# 87 Data len 1750
# 88 Data len 1770
# 89 Data len 1790
# 90 Data len 1810
# 91 Data len 1830
# 92 Data len 1850
# 93 Data len 1870
# 94 Data len 1890
# 95 Data len 1910
# 96 Data len 1930
# 97 Data len 1950
# 98 Data len 1970
# 99 Data len 1990
# 100 Data len 2010
# 101 Data len 2030
# 102 Data len 2050
# 103 Data len 2070
# 104 Data len 2090
# 105 Data len 2110
# 106 Data len 2130
# 107 Data len 2150
# 108 Data len 2170
# 109 Data len 2190
# 110 Data len 2210
# 111 Data len 2230
# 112 Data len 2250
# 113 Data len 2270
# 114 Data len 2290
# 115 Data len 2310
# 116 Data len 2330
# 117 Data len 2350
# 118 Data len 2370
# 119 Data len 2390
# 120 Data len 2410
# 121 Data len 2430
# 122 Data len 2450
# 123 Data len 2470
# 124 Data len 2490
# 125 Data len 2510
# 126 Data len 2530
# 127 Data len 2550
# 128 Data len 2570
# 129 Data len 2590
# 130 Data len 2610
# 131 Data len 2630
# 132 Data len 2650
# 133 Data len 2670
# 134 Data len 2690
# 135 Data len 2710
# 136 Data len 2730
# 137 Data len 2750
# 138 Data len 2770
# 139 Data len 2790
# 140 Data len 2810
# 141 Data len 2830
# 142 Data len 2850
# 143 Data len 2870
# 144 Data len 2890
# 145 Data len 2910
# 146 Data len 2930
# 147 Data len 2950
# 148 Data len 2970
# 149 Data len 2990
# 150 Data len 3010

# %%
df = pd.DataFrame(all_data)
df.head()
# Out:
#   jobType     jobNo             jobName      jobNameSnippet jobRole jobRo  \
# 0       1  12874165              資深行銷專員              資深行銷專員       1     1
# 1       1  11090680             品牌經理/副理             品牌經理/副理       1     1
# 2       1  11904855  資深後端軟體工程師(台中)-線上面試  資深後端軟體工程師(台中)-線上面試       1     1
# 3       1  12771251      急徵餐飲正職人員38000起      急徵餐飲正職人員38000起       1     1
# 4       1  12054607      【營運企劃】業務通路管理人員      【營運企劃】業務通路管理人員       1     1
#
#     jobAddrNo jobAddrNoDesc    jobAddress  \
# 0  6001001005        台北市大安區  敦化南路二段77號17樓
# 1  6001001005        台北市大安區   仁愛路三段26號11樓
# 2  6001008007        台中市西屯區
# 3  6001001007        台北市信義區      松高路12號B2
# 4  6001001005        台北市大安區           台北市
#
#                                          description  ...        tags  \
# 0  主要負責Texas Roadhouse餐飲品牌行銷事項\n1.發展品牌、商品及目標族群的行銷...  ...    [員工250人]
# 1  產品：全球知名精品餐瓷品牌經營管理。\n1.具百貨業零售通路活動企劃執行經驗.\n2.執行品...  ...          []
# 2  ** 應徵時請附上 Cover Letter (自薦信) **\n認真對待所開發的系統，就像...  ...      [遠端工作]
# 3  工作內容：製作餐點(麵線.年糕)、備料及跟客人回應點餐\n\n排班制度: 一天上九小時(包含...  ...     [員工10人]
# 4  【煩請投遞履歷至「國泰人才招募平台」】https://reurl.cc/Q7Ok7o\n--...  ...  [員工33000人]
#
#           landmark                                               link  \
# 0                   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 1  距捷運大安森林公園站450公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 2                   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 3     距捷運市政府站340公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 4                   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
#
#     jobsource          jobNameRaw                       custNameRaw  \
# 0  hotjob_chr              資深行銷專員  開展餐飲集團 Texas Roadhouse_路德斯股份有限公司
# 1  hotjob_chr             品牌經理/副理                   居禮名店_聯友企業股份有限公司
# 2  hotjob_chr  資深後端軟體工程師(台中)-線上面試                        九七科技股份有限公司
# 3  hotjob_chr      急徵餐飲正職人員38000起                 麵線歐爸_萬源整銷文化股份有限公司
# 4  hotjob_chr      【營運企劃】業務通路管理人員             國泰人壽保險股份有限公司_總公司_國泰金控
#
#            lon         lat remoteWorkType                           major
# 0  121.5491721  25.0301071              0                              []
# 1  121.5361564  25.0376226              0                              []
# 2  120.6424333  24.1769764              1  [資訊工程相關, 其他數學及電算機科學相關, 資訊管理相關]
# 3  121.5666758  25.0380379              0                              []
# 4  121.5433783  25.0249441              0              [商業及管理學科類, 數理統計相關]
#
# [5 rows x 40 columns]

# %%
# 檢查有沒有重複的
print(df.shape)
print(len(set(df.jobNo)))

#　拿掉重複的
df = df.drop_duplicates('jobNo')
df.shape
# Out:
# (3010, 40)
# 2253
# (2253, 40)

# %%
df.head()
# Out:
#   jobType     jobNo             jobName      jobNameSnippet jobRole jobRo  \
# 0       1  12874165              資深行銷專員              資深行銷專員       1     1
# 1       1  11090680             品牌經理/副理             品牌經理/副理       1     1
# 2       1  11904855  資深後端軟體工程師(台中)-線上面試  資深後端軟體工程師(台中)-線上面試       1     1
# 3       1  12771251      急徵餐飲正職人員38000起      急徵餐飲正職人員38000起       1     1
# 4       1  12054607      【營運企劃】業務通路管理人員      【營運企劃】業務通路管理人員       1     1
#
#     jobAddrNo jobAddrNoDesc    jobAddress  \
# 0  6001001005        台北市大安區  敦化南路二段77號17樓
# 1  6001001005        台北市大安區   仁愛路三段26號11樓
# 2  6001008007        台中市西屯區
# 3  6001001007        台北市信義區      松高路12號B2
# 4  6001001005        台北市大安區           台北市
#
#                                          description  ...        tags  \
# 0  主要負責Texas Roadhouse餐飲品牌行銷事項\n1.發展品牌、商品及目標族群的行銷...  ...    [員工250人]
# 1  產品：全球知名精品餐瓷品牌經營管理。\n1.具百貨業零售通路活動企劃執行經驗.\n2.執行品...  ...          []
# 2  ** 應徵時請附上 Cover Letter (自薦信) **\n認真對待所開發的系統，就像...  ...      [遠端工作]
# 3  工作內容：製作餐點(麵線.年糕)、備料及跟客人回應點餐\n\n排班制度: 一天上九小時(包含...  ...     [員工10人]
# 4  【煩請投遞履歷至「國泰人才招募平台」】https://reurl.cc/Q7Ok7o\n--...  ...  [員工33000人]
#
#           landmark                                               link  \
# 0                   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 1  距捷運大安森林公園站450公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 2                   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 3     距捷運市政府站340公尺  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
# 4                   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...
#
#     jobsource          jobNameRaw                       custNameRaw  \
# 0  hotjob_chr              資深行銷專員  開展餐飲集團 Texas Roadhouse_路德斯股份有限公司
# 1  hotjob_chr             品牌經理/副理                   居禮名店_聯友企業股份有限公司
# 2  hotjob_chr  資深後端軟體工程師(台中)-線上面試                        九七科技股份有限公司
# 3  hotjob_chr      急徵餐飲正職人員38000起                 麵線歐爸_萬源整銷文化股份有限公司
# 4  hotjob_chr      【營運企劃】業務通路管理人員             國泰人壽保險股份有限公司_總公司_國泰金控
#
#            lon         lat remoteWorkType                           major
# 0  121.5491721  25.0301071              0                              []
# 1  121.5361564  25.0376226              0                              []
# 2  120.6424333  24.1769764              1  [資訊工程相關, 其他數學及電算機科學相關, 資訊管理相關]
# 3  121.5666758  25.0380379              0                              []
# 4  121.5433783  25.0249441              0              [商業及管理學科類, 數理統計相關]
#
# [5 rows x 40 columns]

# %% [markdown]
# # Dump files

# %%
from datetime import datetime
now = datetime.now().strftime("%Y%m%d%H%M%S")
print("Current time: ", now)
# Out:
# 20220620150837

# %% [markdown]
# ## Method 1: by json library

# %%
import json
with open('104_list%s.json'%now, 'w') as outfile:
  json.dump(all_data, outfile)

# %% [markdown]
# ## Method 2: by pandas library

# %%
with open('104_df%s.json'%now, 'w') as f:
  f.write(df.to_json())

# %%
with open('104_df%s.json'%now, 'r') as fin:
  data2 = pd.read_json(fin)
data2.head()
data2.shape
# Out:
# (2279, 40)

# %% [markdown]
# # Clean Version

# %%
headers = {'referer': 'https://www.104.com.tw/'}
search_str = '數據分析'

# Detecting totalPage
url_104 = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=' + search_str + '&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&page=2&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1'

raw = requests.get(url_104, headers=headers).json()
totalPage = raw['data']['totalPage']
print(totalPage)

# Getting data by loop
all_data = []
for page in range(1, totalPage):
    url = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=' + search_str + '&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&' + str(page) + '&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1'
    raw = requests.get(url, headers=headers).json()
    all_data.extend(raw['data']['list'])
    print(len(all_data), end = " ")
print()
df = pd.DataFrame(all_data)
df = df.drop_duplicates('jobNo')

# Saving and Backing up data
from datetime import datetime 

now = datetime.now().strftime("%Y%m%d%H%M%S")
print("Current Time =", now)
with open('104_%s_%s.json'%(search_str, now), 'w') as f:
  f.write(df.to_json())
  
with open('104_%s_%s.json'%(search_str,now), 'r') as fin:
  data = pd.read_json(fin)
data.head()
data.shape
# Out:
# 150
# 30 60 90 120 150 180 210 240 270 300 330 360 390 420 450 480 510 540 570 600 630 660 690 720 750 780 810 840 870 900 930 960 990 1020 1050 1080 1110 1140 1170 1200 1230 1260 1290 1320 1350 1380 1410 1440 1470 1500 1530 1560 1590 1620 1650 1680 1710 1740 1770 1800 1830 1860 1890 1920 1950 1980 2010 2040 2070 2100 2130 2160 2190 2220 2250 2280 2310 2340 2370 2400 2430 2460 2490 2520 2550 2580 2610 2640 2670 2700 2730 2760 2790 2820 2850 2880 2910 2940 2970 3000 3030 3060 3090 3120 3150 3180 3210 3240 3270 3300 3330 3360 3390 3420 3450 3480 3510 3540 3570 3600 3630 3660 3690 3720 3750 3780 3810 3840 3870 3900 3930 3960 3990 4020 4050 4080 4110 4140 4170 4200 4230 4260 4290 4320 4350 4380 4410 4440 4470
# Current Time = 20220620172126
# (58, 40)
